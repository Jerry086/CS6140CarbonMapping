# %% [markdown]
# <a href="https://colab.research.google.com/github/Jerry086/CS6140CarbonMapping/blob/main/Forest_Carbon_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Forest Carbon Mapping

# %% [markdown]
# ## Setting Up Enviornment

# %% [markdown]
# Mount Google Drive to the Colab VM if you want to save and load files from your Google Drive. Please note that the space in your Google Drive is limited, and you may need to upgrade your storage plan if you want to save large files.

# %%
# skip the code if dataset is uploaded or downloaded from Google Cloud Storage
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Authenticate Google Cloud Storage if data is stored and retrieved from it.

# %%
# authenticate google cloud
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# Authenticate and authorize access to Earth Engine.

# %%
# Import, authenticate and initialize the Earth Engine library.
import ee
ee.Authenticate()
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ztq-_eH48dj7wEBoqsnrjKlVYllJinXyF2KMS1sMdow&tc=Nx8lt54O4PkUBTbRI2wsZTGxzjlklg9hr4944pefx6Q&cc=5O0cF3SVRfu4--quCuD5r2p_FMDmKGK0ruS8E_BVfjw
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1Adeu5BX-hGs3qVZOlr-9a0wLvOGt2vwdNsY3863D2k_PxIwssYqACttaUVU
#
# Successfully saved authorization token.

# %% [markdown]
# ## Install & import Python packages

# %% [markdown]
# Import Python packages used throughout this notebook.

# %%
# Folium setup.
import folium
print(folium.__version__)
# Out:
# 0.14.0

# %%
# Tensorflow setup.
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# ## Set global variables

# %%
# Specify names locations for outputs in Google Drive.
# Uncomment the code for Google Drive storage.
# FOLDER = 'dataset'

# Specify names locations for outputs in Google Cloud.
BUCKET = 'cs6140'
FOLDER = 'dataset'
TRAINING_BASE = 'training_patches'
EVAL_BASE = 'eval_patches'

# Specify feature bands to the model and the response variable.
MODIS_BANDS = ['EVI']
COPERNICUS_BANDS = ['discrete_classification', 'forest_type']
TERRA_BANDS = ['Percent_Tree_Cover', 'Percent_NonTree_Vegetation']
BANDS = MODIS_BANDS + COPERNICUS_BANDS + TERRA_BANDS
RESPONSE = 'annualNPP'
FEATURES = BANDS + [RESPONSE]

# Specify the size and shape of patches (256x256 pixels images) expected by the model.
KERNEL_SIZE = 256
KERNEL_SHAPE = [KERNEL_SIZE, KERNEL_SIZE]

# Columns for input features and response
COLUMNS = [
  # Configuration for parsing a fixed-length input feature.
  tf.io.FixedLenFeature(shape=KERNEL_SHAPE, dtype=tf.float32) for k in FEATURES
]
# Label each column with feature name by dictionary
FEATURES_DICT = dict(zip(FEATURES, COLUMNS))

# Sizes of the training and evaluation datasets.
TRAIN_SIZE = 10000
EVAL_SIZE = 5000

# Specify model training parameters.
BATCH_SIZE = 16
EPOCHS = 2
BUFFER_SIZE = 500
OPTIMIZER = 'Adam'
LOSS = 'MeanSquaredError'
METRICS = ['RootMeanSquaredError']

# %% [markdown]
# # Visualizing Images and Image Bands

# %% [markdown]
# This research focuses on Forest Carbon Mapping in North America area

# %%
# Define the region of interest (ROI)
north_america_polygon = ee.Geometry.Polygon([
    [-168, 65],  # Northwest corner (top-left)
    [-168, 10],  # Southwest corner (bottom-left)
    [-52, 10],   # Southeast corner (bottom-right)
    [-52, 65],   # Northeast corner (top-right)
])

# %%
def reduce_collection(filename):
  """The filter function.
  Filter an image collection to the the year of 2018, region of North America
  Reduce temporal data by mean
  Args:
    filename: dataset filename of the collection.
  Returns:
    A representative image.
  """
  collection = ee.ImageCollection(filename)
  filtered = collection.filterDate('2018-01-01', '2018-12-31')
  reduced = filtered.mean().clip(north_america_polygon)
  return reduced

def normalize_band(image, band):
  """The scaling function.
  Scaling an image band within the range [0, 1] by min-max scaler
  Args:
    image: the image.
    band: the band to be scaled.
  Returns:
    A scaled image band.
  """
  image = image.select(band)
  stats = image.reduceRegion(
      reducer=ee.Reducer.minMax(),
      geometry=north_america_polygon,
      scale=250,
      bestEffort=True
  ).getInfo()
  min, max = stats[band + '_min'], stats[band + '_max']
  normalized = image.unitScale(min, max)
  return normalized

# %% [markdown]
# Visualize 'EVI' band from [MOD13Q1.061 Terra Vegetation Indices 16-Day Global 250m](https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MOD13Q1#bands).

# %%
modis_image = reduce_collection("MODIS/061/MOD13Q1")
EVI = normalize_band(modis_image, 'EVI')

# Use folium to visualize the image
mapid = EVI.getMapId({'bands': ['EVI'], 'min': 0, 'max': 1, 'palette': [
    'ffffff', 'ce7e45', 'df923d', 'f1b555', 'fcd163', '99b718', '74a901',
    '66a000', '529400', '3e8601', '207401', '056201', '004c00', '023b01',
    '012e01', '011d01', '011301'
  ]})
# Center in Vancouver
map = folium.Map(location=[49.2827, -123.1207])
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='EVI',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e468322e866376dcc684aa2fb281fa1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e468322e866376dcc684aa2fb281fa1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e468322e866376dcc684aa2fb281fa1 = L.map(
#                 &quot;map_0e468322e866376dcc684aa2fb281fa1&quot;,
#                 {
#                     center: [49.2827, -123.1207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3249a144bc5fcf70595ec5983434a86 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e468322e866376dcc684aa2fb281fa1);
#
#
#             var tile_layer_99a54faa8d56915ffad42665c02f5ab0 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/256ce66ee492a5d711135ffb0047a6d4-d5109d9f9a87dae9e21db5c802a266d6/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e468322e866376dcc684aa2fb281fa1);
#
#
#             var layer_control_b50fa637041b0fecd5d434145b19afd0 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a3249a144bc5fcf70595ec5983434a86,
#                 },
#                 overlays :  {
#                     &quot;EVI&quot; : tile_layer_99a54faa8d56915ffad42665c02f5ab0,
#                 },
#             };
#             L.control.layers(
#                 layer_control_b50fa637041b0fecd5d434145b19afd0.base_layers,
#                 layer_control_b50fa637041b0fecd5d434145b19afd0.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_0e468322e866376dcc684aa2fb281fa1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Visualize 'Discrete_classification' and 'forest_type' bands from [Copernicus Global Land Cover Layers: CGLS-LC100 Collection 3](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_Landcover_100m_Proba-V-C3_Global#bands).

# %%
copernicus_image = reduce_collection("COPERNICUS/Landcover/100m/Proba-V-C3/Global")
discrete_classification = normalize_band(copernicus_image, 'discrete_classification')
forest_type = normalize_band(copernicus_image, 'forest_type')

# Use folium to visualize the image
mapid = discrete_classification.getMapId({'bands': ['discrete_classification'], 'min': 0, 'max': 1, 'palette': [
    '282828', '666000', '009900', '70663e', 'a0dc00', '929900'
  ]})
map = folium.Map(location=[49.2827, -123.1207])
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='discrete_classification',
  ).add_to(map)

mapid = forest_type.getMapId({'bands': ['forest_type'], 'min': 0, 'max': 1, 'palette': [
    '282828', '666000', '009900', '70663e', 'a0dc00', '929900'
  ]})
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='forest_type',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07471b053cfe22354b560404d5f6ec54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07471b053cfe22354b560404d5f6ec54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07471b053cfe22354b560404d5f6ec54 = L.map(
#                 &quot;map_07471b053cfe22354b560404d5f6ec54&quot;,
#                 {
#                     center: [49.2827, -123.1207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2df7b483ab5a5be5dad28853875269a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07471b053cfe22354b560404d5f6ec54);
#
#
#             var tile_layer_bc2cf7f91df4f1a3e49e22e91e4346e1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/3c76891d78c72e3c8a83cf58c350e829-55ba1a02ec25bf0b3bfab9146f3e90b4/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07471b053cfe22354b560404d5f6ec54);
#
#
#             var tile_layer_1b8246c3ede0470aa89901f297afbdcf = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/91b79d015e8a2febad9aee5fab1a57c4-1918301b7843569f8f6b5396ef7a84d9/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07471b053cfe22354b560404d5f6ec54);
#
#
#             var layer_control_0faddd5eaa5f8984109dd97a4a414f24 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_2df7b483ab5a5be5dad28853875269a5,
#                 },
#                 overlays :  {
#                     &quot;discrete_classification&quot; : tile_layer_bc2cf7f91df4f1a3e49e22e91e4346e1,
#                     &quot;forest_type&quot; : tile_layer_1b8246c3ede0470aa89901f297afbdcf,
#                 },
#             };
#             L.control.layers(
#                 layer_control_0faddd5eaa5f8984109dd97a4a414f24.base_layers,
#                 layer_control_0faddd5eaa5f8984109dd97a4a414f24.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_07471b053cfe22354b560404d5f6ec54);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Visualize 'Percent_Tree_Cover' and 'Percent_NonTree_Vegetation' from [MOD44B.006 Terra Vegetation Continuous Fields Yearly Global 250m](https://developers.google.com/earth-engine/datasets/catalog/MODIS_006_MOD44B#bands).

# %%
terra_image = reduce_collection("MODIS/006/MOD44B")
Percent_Tree_Cover = normalize_band(terra_image, 'Percent_Tree_Cover')
Percent_NonTree_Vegetation = normalize_band(terra_image, 'Percent_NonTree_Vegetation')

# Use folium to visualize the image
mapid = Percent_Tree_Cover.getMapId({'bands': ['Percent_Tree_Cover'], 'min': 0, 'max': 1, 'palette': ['bbe029', '0a9501', '074b03']})
map = folium.Map(location=[49.2827, -123.1207])
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='Percent_Tree_Cover',
  ).add_to(map)

mapid = Percent_NonTree_Vegetation.getMapId({'bands': ['Percent_NonTree_Vegetation'], 'min': 0, 'max': 1, 'palette': ['bbe029', '0a9501', '074b03']})
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='Percent_NonTree_Vegetation',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b07580caa876833296fd7e553b271bc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b07580caa876833296fd7e553b271bc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b07580caa876833296fd7e553b271bc9 = L.map(
#                 &quot;map_b07580caa876833296fd7e553b271bc9&quot;,
#                 {
#                     center: [49.2827, -123.1207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d11bbcfb4c1e26e3cfa94dbdb01865f6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b07580caa876833296fd7e553b271bc9);
#
#
#             var tile_layer_203b2faf4126dfb0683712d3fc2c89d9 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/c937653500ca2a8827ce1cdb26ac97d9-cf9a252c7fcc16cffffba83dad9994e5/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b07580caa876833296fd7e553b271bc9);
#
#
#             var tile_layer_bda2a202c9cd13948bd9ba38ca174894 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/fc768e50191fad43d2b8b20153a25c3a-12e84c1d2e829359df429ec5da3a136f/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b07580caa876833296fd7e553b271bc9);
#
#
#             var layer_control_d106eefce6accd90ecc185d468cb67cc = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d11bbcfb4c1e26e3cfa94dbdb01865f6,
#                 },
#                 overlays :  {
#                     &quot;Percent_Tree_Cover&quot; : tile_layer_203b2faf4126dfb0683712d3fc2c89d9,
#                     &quot;Percent_NonTree_Vegetation&quot; : tile_layer_bda2a202c9cd13948bd9ba38ca174894,
#                 },
#             };
#             L.control.layers(
#                 layer_control_d106eefce6accd90ecc185d468cb67cc.base_layers,
#                 layer_control_d106eefce6accd90ecc185d468cb67cc.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_b07580caa876833296fd7e553b271bc9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Response: the amount of carbon captured by plants in an ecosystem, after accounting for losses due to respiration, from [MODIS Net Primary Production CONUS](https://developers.google.com/earth-engine/datasets/catalog/UMT_NTSG_v2_MODIS_NPP#bands).

# %%
npp_image = reduce_collection('UMT/NTSG/v2/MODIS/NPP')
annualNPP = normalize_band(npp_image, 'annualNPP')

mapid = annualNPP.getMapId({'bands': ['annualNPP'], 'min': 0, 'max': 1, 'palette': ['bbe029', '0a9501', '074b03']})
map = folium.Map(location=[38., -122.5])
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='npp',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f8ac419adc8416dabacc397dd96bd5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f8ac419adc8416dabacc397dd96bd5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f8ac419adc8416dabacc397dd96bd5e = L.map(
#                 &quot;map_4f8ac419adc8416dabacc397dd96bd5e&quot;,
#                 {
#                     center: [38.0, -122.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9229377d3ec057abb7a55c9ae7224d86 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f8ac419adc8416dabacc397dd96bd5e);
#
#
#             var tile_layer_765da98264b088933008b8ab14e61526 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/4e0f7deb591c2c848d49b50e4b4f48a1-e5182435f0f5818e8ceca7eb8545ed90/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f8ac419adc8416dabacc397dd96bd5e);
#
#
#             var layer_control_89275c849af8bcb57821a8de6cfb4cae = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_9229377d3ec057abb7a55c9ae7224d86,
#                 },
#                 overlays :  {
#                     &quot;npp&quot; : tile_layer_765da98264b088933008b8ab14e61526,
#                 },
#             };
#             L.control.layers(
#                 layer_control_89275c849af8bcb57821a8de6cfb4cae.base_layers,
#                 layer_control_89275c849af8bcb57821a8de6cfb4cae.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_4f8ac419adc8416dabacc397dd96bd5e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Stack the 2D images (Feature Bands and Response) to create a single image from which samples can be taken. Convert the image into an array image in which each pixel stores 256x256 patches of pixels for each band. To export training patches, convert a multi-band image to an array image using neighborhoodToArray(), then sample the image at points.

# %%
featureStack = ee.Image.cat([
  EVI.select('EVI'),
  discrete_classification.select('discrete_classification'),
  forest_type.select('forest_type'),
  Percent_Tree_Cover.select('Percent_Tree_Cover'),
  Percent_NonTree_Vegetation.select('Percent_NonTree_Vegetation'),
  annualNPP.select('annualNPP')
]).float()

list = ee.List.repeat(1, KERNEL_SIZE)
lists = ee.List.repeat(list, KERNEL_SIZE)
kernel = ee.Kernel.fixed(KERNEL_SIZE, KERNEL_SIZE, lists)

arrays = featureStack.neighborhoodToArray(kernel)

# %% [markdown]
# Utilize geometries from various U.S. states to extract samples from the stack at strategic points, focusing on areas with the highest forest coverage. Specifically, these are imported polygons in which to take the 256x256 samples. Display the sampling polygons on a map, red for training polygons, blue for evaluation.

# %%
usa = ee.FeatureCollection('projects/ee-jariwaladh0/assets/usa')
trainingPolys = usa.filter(ee.Filter.inList('shapeName', ['Maine', 'Alabama', 'South Carolina', 'New Hampshire','West Virginia','Vermont']));
evalPolys = usa.filter(ee.Filter.inList('shapeName', ['Georgia', 'Virginia']));

polyImage = ee.Image(0).byte().paint(trainingPolys, 1).paint(evalPolys, 2)
polyImage = polyImage.updateMask(polyImage)

mapid = polyImage.getMapId({'min': 1, 'max': 2, 'palette': ['red', 'blue']})
map = folium.Map(location=[38., -100.], zoom_start=5)
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='training polygons',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa5279ed2298fc3fe82776b7c21c90d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa5279ed2298fc3fe82776b7c21c90d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa5279ed2298fc3fe82776b7c21c90d1 = L.map(
#                 &quot;map_fa5279ed2298fc3fe82776b7c21c90d1&quot;,
#                 {
#                     center: [38.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec5417b71f792a1f46966c8e8d748297 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fa5279ed2298fc3fe82776b7c21c90d1);
#
#
#             var tile_layer_67f7c038174fe960bab5500120b8824f = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/d4992ecc5e2bd25f3a4c10f6a6b85bce-632127621ccfeeb69462f085e685de67/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fa5279ed2298fc3fe82776b7c21c90d1);
#
#
#             var layer_control_28ae8d9954b3cdcd49bd94b3910bf5b1 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ec5417b71f792a1f46966c8e8d748297,
#                 },
#                 overlays :  {
#                     &quot;training polygons&quot; : tile_layer_67f7c038174fe960bab5500120b8824f,
#                 },
#             };
#             L.control.layers(
#                 layer_control_28ae8d9954b3cdcd49bd94b3910bf5b1.base_layers,
#                 layer_control_28ae8d9954b3cdcd49bd94b3910bf5b1.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_fa5279ed2298fc3fe82776b7c21c90d1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Sampling
#
# Take a sample from each polygon and merge the results into a single export.  The key step is sampling the array image at points, to get all the pixels in a 256x256 neighborhood at each point. Export a single TFRecord file that contains patches of pixel values in each record to build the training and testing data for the model. Since each record potentially contains a lot of data (especially with big patches or many input bands), some manual sharding of the computation is necessary to avoid the `computed value too large` error.  Specifically, the following code takes multiple (smaller) samples within each geometry, merging the results to get a single export.

# %%
# Convert the feature collections to lists for iteration.
trainingPolysList = trainingPolys.toList(trainingPolys.size())
evalPolysList = evalPolys.toList(evalPolys.size())

n = 200 # Number of shards in each polygon, reduced to 200 samples
N = 2000 # Total sample size in each polygon.

# Export all the training data (in many pieces), with one task per geometry.
for g in range(trainingPolys.size().getInfo()):
  geomSample = ee.FeatureCollection([])
  # randomly choose one sample in each iteration
  for i in range(n):
    sample = arrays.sample(
      region = ee.Feature(trainingPolysList.get(g)).geometry(),
      scale = 250,
      numPixels = N / n, # Size of the shard.
      seed = i,
      tileScale = 8
    )
    geomSample = geomSample.merge(sample)

  desc = TRAINING_BASE + '_g' + str(g)
  task = ee.batch.Export.table.toCloudStorage(
    collection = geomSample,
    description = desc,
    # Google Cloud Storage export, for Google Drive export, refer to toDrive()
    bucket = BUCKET,
    fileNamePrefix = FOLDER + '/' + desc,
    fileFormat = 'TFRecord',
    selectors = BANDS + [RESPONSE]
  )
  task.start()

# Export all the evaluation data.
for g in range(evalPolys.size().getInfo()):
  geomSample = ee.FeatureCollection([])
  for i in range(n):
    sample = arrays.sample(
      region = ee.Feature(evalPolysList.get(g)).geometry(),
      scale = 250,
      numPixels = N / n,
      seed = i,
      tileScale = 8
    )
    geomSample = geomSample.merge(sample)

  desc = EVAL_BASE + '_g' + str(g)
  task = ee.batch.Export.table.toCloudStorage(
    collection = geomSample,
    description = desc,
    # Google Cloud Storage export, for Google Drive export, refer to toDrive()
    bucket = BUCKET,
    fileNamePrefix = FOLDER + '/' + desc,
    fileFormat = 'TFRecord',
    selectors = BANDS + [RESPONSE]
  )
  task.start()

# %% [markdown]
# # Training data
#
# Load the data exported from Earth Engine into a `tf.data.Dataset`.

# %%
def parse_tfrecord(example_proto):
  """The parsing function.
  Read a serialized example into the structure defined by FEATURES_DICT.
  Args:
    example_proto: a serialized Example.
  Returns:
    A dictionary of tensors, keyed by feature name.
  """
  return tf.io.parse_single_example(example_proto, FEATURES_DICT)


def to_tuple(inputs):
  """Function to convert a dictionary of tensors to a tuple of (inputs, outputs).
  Turn the tensors returned by parse_tfrecord into a stack in HWC shape.
  Args:
    inputs: A dictionary of tensors, keyed by feature name.
  Returns:
    A tuple of (inputs, outputs).
  """
  inputsList = [inputs.get(key) for key in FEATURES]
  stacked = tf.stack(inputsList, axis=0)
  # Convert from CHW to HWC
  stacked = tf.transpose(stacked, [1, 2, 0])
  return stacked[:,:,:len(BANDS)], stacked[:,:,len(BANDS):]


def get_dataset(pattern):
  """Function to read, parse and format to tuple a set of input tfrecord files.
  Get all the files matching the pattern, parse and convert to tuple.
  Args:
    pattern: A file pattern to match in a Cloud Storage bucket.
  Returns:
    A tf.data.Dataset
  """
  glob = tf.io.gfile.glob(pattern)
  dataset = tf.data.TFRecordDataset(glob, compression_type='GZIP')
  dataset = dataset.map(parse_tfrecord, num_parallel_calls=5)
  dataset = dataset.map(to_tuple, num_parallel_calls=5)
  return dataset

# %% [markdown]
# Use the helpers to read in the training dataset.  Print the first record to check.

# %%
def get_training_dataset():
	"""Get the preprocessed training dataset
  Returns:
    A tf.data.Dataset of training data.
  """
	# directory for Google Cloud Storage, to read from Google Drive, modify 'glob' accordingly
	glob = 'gs://' + BUCKET + '/' + FOLDER + '/' + TRAINING_BASE + '*'
	dataset = get_dataset(glob)
	# shuffle in n iterations, random pick one element from buffer in each iteration
	# batch in size BATCH_SIZE
	# repeat when all element are comsumed
	dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
	return dataset

training = get_training_dataset()
print(iter(training.take(1)).next())
# Out:
# (<tf.Tensor: shape=(16, 256, 256, 5), dtype=float32, numpy=
# array([[[[0.6880596 , 0.57      , 0.8       , 0.8452381 , 0.21428572],
#          [0.69240767, 0.57      , 0.8       , 0.78571427, 0.25510204],
#          [0.66608185, 0.62      , 0.        , 0.71428573, 0.31632653],
#          ...,
#          [0.675602  , 0.2       , 0.        , 0.20238096, 0.6938776 ],
#          [0.7308017 , 0.63      , 0.        , 0.20238096, 0.74489796],
#          ...,
#          [0.7025699 , 0.57      , 0.8       , 0.72619045, 0.33673468],
#          [0.71372306, 0.57      , 0.8       , 0.7619048 , 0.29591838],
#          [0.69723094, 0.57      , 0.8       , 0.72619045, 0.3265306 ]],
#
#         [[0.6917908 , 0.15      , 0.        , 0.20238096, 0.7346939 ],
#          [0.6725837 , 0.2       , 0.        , 0.20238096, 0.7244898 ],
#          [0.7035254 , 0.2       , 0.        , 0.17857143, 0.74489796],
#          ...,
#          [0.70657915, 0.57      , 0.8       , 0.72619045, 0.3265306 ],
#          [0.6946221 , 0.57      , 0.8       , 0.71428573, 0.33673468],
#          [0.6804708 , 0.57      , 0.8       , 0.70238096, 0.3469388 ]],
#
#         [[0.7108665 , 0.2       , 0.        , 0.1904762 , 0.7244898 ],
#          [0.66993946, 0.2       , 0.        , 0.16666667, 0.70408165],
#          [0.665283  , 0.2       , 0.        , 0.16666667, 0.71428573],
#          ...,
#          [0.68156284, 0.57      , 0.8       , 0.71428573, 0.33673468],
#          [0.70341927, 0.57      , 0.8       , 0.75      , 0.30612245],
#          [0.69668996, 0.57      , 0.8       , 0.61904764, 0.41836736]]]],
#       dtype=float32)>, <tf.Tensor: shape=(16, 256, 256, 1), dtype=float32, numpy=
# array([[[[0.3587677 ],
#          [0.35924584],
#          [0.36047545],
#          ...,
#          [0.32061616],
#          [0.32177743],
#          [0.3243391 ]],
#
#         [[0.35299543],
#          [0.35552293],
#          [0.35887015],
#          ...,
#          [0.32850605],
#          [0.3306237 ],
#          [0.33342442]],
#
#         [[0.35210738],
#          [0.35367852],
#          [0.354225  ],
#          ...,
#          [0.32642257],
#          [0.32645673],
#          [0.327618  ]],
#
#         ...,
#
#         [[0.3195915 ],
#          [0.31108683],
#          [0.        ],
#          ...,
#          [0.5008539 ],
#          [0.47479337],
#          [0.28198647]],
#
#         [[0.        ],
#          [0.        ],
#          [0.32252887],
#          ...,
#          [0.28355762],
#          [0.28369424],
#          [0.2907644 ]],
#
#         [[0.3247148 ],
#          [0.33202404],
#          [0.33581528],
#          ...,
#          [0.27269623],
#          [0.28393334],
#          [0.28823692]]],
#
#
#        [[[0.32334858],
#          [0.32307535],
#          [0.32328027],
#          ...,
#          [0.        ],
#          [0.48575723],
#          [0.        ]],
#
#         [[0.32580778],
#          [0.32683244],
#          [0.32638842],
#          ...,
#          [0.49737003],
#          [0.        ],
#          [0.        ]],
#
#         [[0.32355353],
#          [0.3222556 ],
#          [0.32123095],
#          ...,
#          [0.        ],
#          [0.27976638],
#          [0.26504543]],
#
#         ...,
#
#         [[0.33605438],
#          [0.33967483],
#          [0.31692737],
#          ...,
#          [0.37898764],
#          [0.38031968],
#          [0.38294965]],
#
#         [[0.33851355],
#          [0.34028962],
#          [0.20489788],
#          ...,
#          [0.37652844],
#          [0.37796298],
#          [0.3805588 ]],
#
#         [[0.33584943],
#          [0.3354396 ],
#          [0.33407336],
#          ...,
#          [0.36938998],
#          [0.36710158],
#          [0.36535966]]],
#
#
#        [[[0.30944738],
#          [0.3122481 ],
#          [0.3134094 ],
#          ...,
#          [0.33117017],
#          [0.33660087],
#          [0.3370107 ]],
#
#         [[0.311565  ],
#          [0.31692737],
#          [0.31774712],
#          ...,
#          [0.33417583],
#          [0.33455154],
#          [0.33332196]],
#
#         [[0.31532207],
#          [0.30661246],
#          [0.3105062 ],
#          ...,
#          [0.33400506],
#          [0.33021381],
#          [0.32980394]],
#
#         ...,
#
#         [[0.30838856],
#          [0.30975476],
#          [0.3083544 ],
#          ...,
#          [0.32905254],
#          [0.32994056],
#          [0.32871097]],
#
#         [[0.3017624 ],
#          [0.3074322 ],
#          [0.3068174 ],
#          ...,
#          [0.3276863 ],
#          [0.32925746],
#          [0.32935992]],
#
#         [[0.3034702 ],
#          [0.30282122],
#          [0.30087438],
#          ...,
#          [0.33257052],
#          [0.33198988],
#          [0.33161417]]],
#
#
#        ...,
#
#
#        [[[0.38281304],
#          [0.3899515 ],
#          [0.39517727],
#          ...,
#          [0.32256302],
#          [0.3188401 ],
#          [0.33581528]],
#
#         [[0.37294215],
#          [0.37622106],
#          [0.38072956],
#          ...,
#          [0.33724982],
#          [0.3352005 ],
#          [0.3408703 ]],
#
#         [[0.3806271 ],
#          [0.3745133 ],
#          [0.37318122],
#          ...,
#          [0.3534053 ],
#          [0.3515609 ],
#          [0.35419086]],
#
#         ...,
#
#         [[0.32638842],
#          [0.35357606],
#          [0.3534053 ],
#          ...,
#          [0.37642598],
#          [0.37482068],
#          [0.374889  ]],
#
#         [[0.32269964],
#          [0.21562265],
#          [0.35572785],
#          ...,
#          [0.3761186 ],
#          [0.3713027 ],
#          [0.37225902]],
#
#         [[0.35292712],
#          [0.32522714],
#          [0.3247148 ],
#          ...,
#          [0.37949997],
#          [0.37792882],
#          [0.3744108 ]]],
#
#
#        [[[0.3140925 ],
#          [0.31313613],
#          [0.3128629 ],
#          ...,
#          [0.34059703],
#          [0.3390942 ],
#          [0.33844525]],
#
#         [[0.31634673],
#          [0.3160735 ],
#          [0.31436574],
#          ...,
#          [0.34312454],
#          [0.34151924],
#          [0.33967483]],
#
#         [[0.31720063],
#          [0.31962565],
#          [0.31924996],
#          ...,
#          [0.33919665],
#          [0.33554205],
#          [0.33683994]],
#
#         ...,
#
#         [[0.31310198],
#          [0.31047204],
#          [0.30500716],
#          ...,
#          [0.31498054],
#          [0.31146252],
#          [0.31204316]],
#
#         [[0.3137851 ],
#          [0.31190655],
#          [0.31248719],
#          ...,
#          [0.31532207],
#          [0.31648338],
#          [0.31549287]],
#
#         [[0.31511715],
#          [0.3140925 ],
#          [0.3129312 ],
#          ...,
#          [0.31296536],
#          [0.3174397 ],
#          [0.3195915 ]]],
#
#
#        [[[0.29547784],
#          [0.29616094],
#          [0.29370177],
#          ...,
#          [0.33035043],
#          [0.33017966],
#          [0.32826695]],
#
#         [[0.29407746],
#          [0.29195982],
#          [0.2893982 ],
#          ...,
#          [0.3307603 ],
#          [0.32758385],
#          [0.32450986]],
#
#         [[0.29192567],
#          [0.28898832],
#          [0.29223308],
#          ...,
#          [0.3227338 ],
#          [0.3204454 ],
#          [0.31487808]],
#
#         ...,
#
#         [[0.3057586 ],
#          [0.30739805],
#          [0.3093449 ],
#          ...,
#          [0.33287793],
#          [0.3339709 ],
#          [0.33663502]],
#
#         [[0.30439237],
#          [0.2980395 ],
#          [0.29646835],
#          ...,
#          [0.33294624],
#          [0.3112576 ],
#          [0.33629346]],
#
#         [[0.29424825],
#          [0.        ],
#          [0.        ],
#          ...,
#          [0.3308286 ],
#          [0.33646423],
#          [0.3378646 ]]]], dtype=float32)>)

# %% [markdown]
# # Evaluation data
#
# Now do the same thing to get an evaluation dataset.  Note that unlike the training dataset, the evaluation dataset has a batch size of 1, is not repeated and is not shuffled.

# %%
def get_eval_dataset():
	"""Get the preprocessed evaluation dataset
  Returns:
    A tf.data.Dataset of evaluation data.
  """
	# directory for Google Cloud Storage, to read from Google Drive, modify 'glob' accordingly
	glob = 'gs://' + BUCKET + '/' + FOLDER + '/' + EVAL_BASE + '*'
	dataset = get_dataset(glob)
	dataset = dataset.batch(1).repeat()
	return dataset

evaluation = get_eval_dataset()
evaluation
# Out:
# <_RepeatDataset element_spec=(TensorSpec(shape=(None, 256, 256, 5), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None))>

# %% [markdown]
# # Model
#
# Keras implementation of the U-Net model.  The U-Net model takes 256x256 pixel patches as input and a continuous output per-pixel.  We will use mean squared error loss on the sigmoidal output since we are treating this as a regression problem.

# %%
from keras.models import *
from keras.layers import *
from keras import metrics
from keras import optimizers
from keras import losses

def conv_block(input_tensor, num_filters):
	encoder = Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
	encoder = BatchNormalization()(encoder)
	encoder = Activation('relu')(encoder)
	encoder = Conv2D(num_filters, (3, 3), padding='same')(encoder)
	encoder = BatchNormalization()(encoder)
	encoder = Activation('relu')(encoder)
	return encoder

def encoder_block(input_tensor, num_filters):
	encoder = conv_block(input_tensor, num_filters)
	encoder_pool = MaxPooling2D((2, 2), strides=(2, 2))(encoder)
	return encoder_pool, encoder

def decoder_block(input_tensor, concat_tensor, num_filters):
	decoder = Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
	decoder = concatenate([concat_tensor, decoder], axis=-1)
	decoder = BatchNormalization()(decoder)
	decoder = Activation('relu')(decoder)
	decoder = Conv2D(num_filters, (3, 3), padding='same')(decoder)
	decoder = BatchNormalization()(decoder)
	decoder = Activation('relu')(decoder)
	decoder = Conv2D(num_filters, (3, 3), padding='same')(decoder)
	decoder = BatchNormalization()(decoder)
	decoder = Activation('relu')(decoder)
	return decoder

def get_model():
	inputs = Input(shape=[None, None, len(BANDS)]) # 256
	encoder0_pool, encoder0 = encoder_block(inputs, 32) # 128
	encoder1_pool, encoder1 = encoder_block(encoder0_pool, 64) # 64
	encoder2_pool, encoder2 = encoder_block(encoder1_pool, 128) # 32
	encoder3_pool, encoder3 = encoder_block(encoder2_pool, 256) # 16
	encoder4_pool, encoder4 = encoder_block(encoder3_pool, 512) # 8
	center = conv_block(encoder4_pool, 1024) # center
	decoder4 = decoder_block(center, encoder4, 512) # 16
	decoder3 = decoder_block(decoder4, encoder3, 256) # 32
	decoder2 = decoder_block(decoder3, encoder2, 128) # 64
	decoder1 = decoder_block(decoder2, encoder1, 64) # 128
	decoder0 = decoder_block(decoder1, encoder0, 32) # 256
	outputs = Conv2D(1, (1, 1), activation='sigmoid')(decoder0)

	model = Model(inputs=[inputs], outputs=[outputs])

	model.compile(
		optimizer=optimizers.get(OPTIMIZER),
		loss=losses.get(LOSS),
		metrics=[metrics.get(metric) for metric in METRICS])

	return model

# %% [markdown]
# # Training the model
#
# Here we're going to train for 2 epochs, where the loss reaches a plateau experimentally

# %%
m = get_model()

m.fit(
    x=training,
    epochs=EPOCHS,
    steps_per_epoch=int(TRAIN_SIZE / BATCH_SIZE),
    validation_data=evaluation,
    validation_steps=EVAL_SIZE)

# Save the weights after training
m.save_weights('drive/My Drive/dataset/params/normalized')
# Out:
# Epoch 1/2
# 625/625 [==============================] - 1105s 2s/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0882 - val_root_mean_squared_error: 0.2969
# Epoch 2/2
# 625/625 [==============================] - 1003s 2s/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1744

# %%
# Display the model's architecture
m.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  5)]
#
#  conv2d_23 (Conv2D)             (None, None, None,   1472        ['input_2[0][0]']
#                                 32)
#
#  batch_normalization_27 (BatchN  (None, None, None,   128        ['conv2d_23[0][0]']
#  ormalization)                  32)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 32)
#
#  conv2d_24 (Conv2D)             (None, None, None,   9248        ['activation_27[0][0]']
#                                 32)
#
#  batch_normalization_28 (BatchN  (None, None, None,   128        ['conv2d_24[0][0]']
#  ormalization)                  32)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 32)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, None, None,   0          ['activation_28[0][0]']
#                                 32)
#
#  conv2d_25 (Conv2D)             (None, None, None,   18496       ['max_pooling2d_5[0][0]']
#                                 64)
#
#  batch_normalization_29 (BatchN  (None, None, None,   256        ['conv2d_25[0][0]']
#  ormalization)                  64)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 64)
#
#  conv2d_26 (Conv2D)             (None, None, None,   36928       ['activation_29[0][0]']
#                                 64)
#
#  batch_normalization_30 (BatchN  (None, None, None,   256        ['conv2d_26[0][0]']
#  ormalization)                  64)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 64)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, None, None,   0          ['activation_30[0][0]']
#                                 64)
#
#  conv2d_27 (Conv2D)             (None, None, None,   73856       ['max_pooling2d_6[0][0]']
#                                 128)
#
#  batch_normalization_31 (BatchN  (None, None, None,   512        ['conv2d_27[0][0]']
#  ormalization)                  128)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 128)
#
#  conv2d_28 (Conv2D)             (None, None, None,   147584      ['activation_31[0][0]']
#                                 128)
#
#  batch_normalization_32 (BatchN  (None, None, None,   512        ['conv2d_28[0][0]']
#  ormalization)                  128)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 128)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, None, None,   0          ['activation_32[0][0]']
#                                 128)
#
#  conv2d_29 (Conv2D)             (None, None, None,   295168      ['max_pooling2d_7[0][0]']
#                                 256)
#
#  batch_normalization_33 (BatchN  (None, None, None,   1024       ['conv2d_29[0][0]']
#  ormalization)                  256)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 256)
#
#  conv2d_30 (Conv2D)             (None, None, None,   590080      ['activation_33[0][0]']
#                                 256)
#
#  batch_normalization_34 (BatchN  (None, None, None,   1024       ['conv2d_30[0][0]']
#  ormalization)                  256)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 256)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, None, None,   0          ['activation_34[0][0]']
#                                 256)
#
#  conv2d_31 (Conv2D)             (None, None, None,   1180160     ['max_pooling2d_8[0][0]']
#                                 512)
#
#  batch_normalization_35 (BatchN  (None, None, None,   2048       ['conv2d_31[0][0]']
#  ormalization)                  512)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 512)
#
#  conv2d_32 (Conv2D)             (None, None, None,   2359808     ['activation_35[0][0]']
#                                 512)
#
#  batch_normalization_36 (BatchN  (None, None, None,   2048       ['conv2d_32[0][0]']
#  ormalization)                  512)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 512)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, None, None,   0          ['activation_36[0][0]']
#                                 512)
#
#  conv2d_33 (Conv2D)             (None, None, None,   4719616     ['max_pooling2d_9[0][0]']
#                                 1024)
#
#  batch_normalization_37 (BatchN  (None, None, None,   4096       ['conv2d_33[0][0]']
#  ormalization)                  1024)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 1024)
#
#  conv2d_34 (Conv2D)             (None, None, None,   9438208     ['activation_37[0][0]']
#                                 1024)
#
#  batch_normalization_38 (BatchN  (None, None, None,   4096       ['conv2d_34[0][0]']
#  ormalization)                  1024)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 1024)
#
#  conv2d_transpose_5 (Conv2DTran  (None, None, None,   2097664    ['activation_38[0][0]']
#  spose)                         512)
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['activation_36[0][0]',
#                                 1024)                             'conv2d_transpose_5[0][0]']
#
#  batch_normalization_39 (BatchN  (None, None, None,   4096       ['concatenate_5[0][0]']
#  ormalization)                  1024)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 1024)
#
#  conv2d_35 (Conv2D)             (None, None, None,   4719104     ['activation_39[0][0]']
#                                 512)
#
#  batch_normalization_40 (BatchN  (None, None, None,   2048       ['conv2d_35[0][0]']
#  ormalization)                  512)
#
#  activation_40 (Activation)     (None, None, None,   0           ['batch_normalization_40[0][0]']
#                                 512)
#
#  conv2d_36 (Conv2D)             (None, None, None,   2359808     ['activation_40[0][0]']
#                                 512)
#
#  batch_normalization_41 (BatchN  (None, None, None,   2048       ['conv2d_36[0][0]']
#  ormalization)                  512)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 512)
#
#  conv2d_transpose_6 (Conv2DTran  (None, None, None,   524544     ['activation_41[0][0]']
#  spose)                         256)
#
#  concatenate_6 (Concatenate)    (None, None, None,   0           ['activation_34[0][0]',
#                                 512)                              'conv2d_transpose_6[0][0]']
#
#  batch_normalization_42 (BatchN  (None, None, None,   2048       ['concatenate_6[0][0]']
#  ormalization)                  512)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 512)
#
#  conv2d_37 (Conv2D)             (None, None, None,   1179904     ['activation_42[0][0]']
#                                 256)
#
#  batch_normalization_43 (BatchN  (None, None, None,   1024       ['conv2d_37[0][0]']
#  ormalization)                  256)
#
#  activation_43 (Activation)     (None, None, None,   0           ['batch_normalization_43[0][0]']
#                                 256)
#
#  conv2d_38 (Conv2D)             (None, None, None,   590080      ['activation_43[0][0]']
#                                 256)
#
#  batch_normalization_44 (BatchN  (None, None, None,   1024       ['conv2d_38[0][0]']
#  ormalization)                  256)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 256)
#
#  conv2d_transpose_7 (Conv2DTran  (None, None, None,   131200     ['activation_44[0][0]']
#  spose)                         128)
#
#  concatenate_7 (Concatenate)    (None, None, None,   0           ['activation_32[0][0]',
#                                 256)                              'conv2d_transpose_7[0][0]']
#
#  batch_normalization_45 (BatchN  (None, None, None,   1024       ['concatenate_7[0][0]']
#  ormalization)                  256)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 256)
#
#  conv2d_39 (Conv2D)             (None, None, None,   295040      ['activation_45[0][0]']
#                                 128)
#
#  batch_normalization_46 (BatchN  (None, None, None,   512        ['conv2d_39[0][0]']
#  ormalization)                  128)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 128)
#
#  conv2d_40 (Conv2D)             (None, None, None,   147584      ['activation_46[0][0]']
#                                 128)
#
#  batch_normalization_47 (BatchN  (None, None, None,   512        ['conv2d_40[0][0]']
#  ormalization)                  128)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 128)
#
#  conv2d_transpose_8 (Conv2DTran  (None, None, None,   32832      ['activation_47[0][0]']
#  spose)                         64)
#
#  concatenate_8 (Concatenate)    (None, None, None,   0           ['activation_30[0][0]',
#                                 128)                              'conv2d_transpose_8[0][0]']
#
#  batch_normalization_48 (BatchN  (None, None, None,   512        ['concatenate_8[0][0]']
#  ormalization)                  128)
#
#  activation_48 (Activation)     (None, None, None,   0           ['batch_normalization_48[0][0]']
#                                 128)
#
#  conv2d_41 (Conv2D)             (None, None, None,   73792       ['activation_48[0][0]']
#                                 64)
#
#  batch_normalization_49 (BatchN  (None, None, None,   256        ['conv2d_41[0][0]']
#  ormalization)                  64)
#
#  activation_49 (Activation)     (None, None, None,   0           ['batch_normalization_49[0][0]']
#                                 64)
#
#  conv2d_42 (Conv2D)             (None, None, None,   36928       ['activation_49[0][0]']
#                                 64)
#
#  batch_normalization_50 (BatchN  (None, None, None,   256        ['conv2d_42[0][0]']
#  ormalization)                  64)
#
#  activation_50 (Activation)     (None, None, None,   0           ['batch_normalization_50[0][0]']
#                                 64)
#
#  conv2d_transpose_9 (Conv2DTran  (None, None, None,   8224       ['activation_50[0][0]']
#  spose)                         32)
#
#  concatenate_9 (Concatenate)    (None, None, None,   0           ['activation_28[0][0]',
#                                 64)                               'conv2d_transpose_9[0][0]']
#
#  batch_normalization_51 (BatchN  (None, None, None,   256        ['concatenate_9[0][0]']
#  ormalization)                  64)
#
#  activation_51 (Activation)     (None, None, None,   0           ['batch_normalization_51[0][0]']
#                                 64)
#
#  conv2d_43 (Conv2D)             (None, None, None,   18464       ['activation_51[0][0]']
#                                 32)
#
#  batch_normalization_52 (BatchN  (None, None, None,   128        ['conv2d_43[0][0]']
#  ormalization)                  32)
#
#  activation_52 (Activation)     (None, None, None,   0           ['batch_normalization_52[0][0]']
#                                 32)
#
#  conv2d_44 (Conv2D)             (None, None, None,   9248        ['activation_52[0][0]']
#                                 32)
#
#  batch_normalization_53 (BatchN  (None, None, None,   128        ['conv2d_44[0][0]']
#  ormalization)                  32)
#
#  activation_53 (Activation)     (None, None, None,   0           ['batch_normalization_53[0][0]']
#                                 32)
#
#  conv2d_45 (Conv2D)             (None, None, None,   33          ['activation_53[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 31,127,073
# Trainable params: 31,111,073
# Non-trainable params: 16,000
# __________________________________________________________________________________________________

# %% [markdown]
# # Retriving the model's weights
#
# To avoid retrain the model, we can retrive its weights

# %%
m = get_model()
# Restore the weights
m.load_weights('drive/My Drive/dataset/params/normalized')

# Evaluate the model
loss, acc = m.evaluate(x=evaluation, verbose=2, steps=1000)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 1000/1000 - 769s - loss: 0.0392 - root_mean_squared_error: 0.1980 - 769s/epoch - 769ms/step
# Restored model, accuracy: 19.80%

# %% [markdown]
# # Prediction
#
# The prediction pipeline is:
#
# 1.  Export imagery on which to do predictions from Earth Engine in TFRecord format to a Cloud Storage bucket.
# 2.  Use the trained model to make the predictions.
# 3.  Write the predictions to a TFRecord file in a Cloud Storage.
# 4.  Upload the predictions TFRecord file to Earth Engine.

# %%
def doExport(inputs, out_image_base, kernel_buffer, region):
  """Run the image export task.  Block until complete.
  """
  task = ee.batch.Export.image.toCloudStorage(
    image = inputs.select(BANDS),
    description = out_image_base,
    # Google Cloud Storage export, for Google Drive export, refer to toDrive()
    bucket = BUCKET,
    fileNamePrefix = FOLDER + '/' + out_image_base,
    region = region.getInfo()['coordinates'],
    scale = 250,
    fileFormat = 'TFRecord',
    maxPixels = 1e10,
    formatOptions = {
      'patchDimensions': KERNEL_SHAPE,
      'kernelSize': kernel_buffer,
      'compressed': True,
      'maxFileSize': 104857600
    }
  )
  task.start()

  # Block until the task completes.
  print('Running image export to Google Cloud/Drive...')
  import time
  while task.active():
    time.sleep(30)

  # Error condition
  if task.status()['state'] != 'COMPLETED':
    print('Error with image export.')
  else:
    print('Image export completed.')

# %% [markdown]
# Now there's all the code needed to run the prediction pipeline, all that remains is to specify the output region in which to do the prediction, the names of the output files, where to put them, and the shape of the outputs.  In terms of the shape, the model is trained on 256x256 patches, but can work (in theory) on any patch that's big enough with even dimensions.  Because of tile boundary artifacts, give the model slightly larger patches for prediction, then clip out the middle 256x256 patch.  This is controlled with a kernel buffer, half the size of which will extend beyond the kernel buffer.  For example, specifying a 128x128 kernel will append 64 pixels on each side of the patch, to ensure that the pixels in the output are taken from inputs completely covered by the kernel.

# %%
# prepare for prediction
m = get_model()
# Restore the weights that have been uploaded to Google Cloud Storage
m.load_weights('gs://cs6140/params/normalized')

# %%
# input features
inputs = ee.Image.cat([
  EVI.select('EVI'),
  discrete_classification.select('discrete_classification'),
  forest_type.select('forest_type'),
  Percent_Tree_Cover.select('Percent_Tree_Cover'),
  Percent_NonTree_Vegetation.select('Percent_NonTree_Vegetation')
]).float()

# %% [markdown]
# ##Prediction for the US region

# %%
# Output assets folder:
user_folder = 'users/weizhon'

# Base file name to use for TFRecord files and assets.
us_image_base = 'region_US_'
# Half this will extend on the sides of each patch.
us_kernel_buffer = [128, 128]

# US
us_region = ee.Geometry.Polygon(
        [[[-124.81863747950683,48.366802253368554],
          [-124.64285622950683,39.39753877975156],
          [-117.78738747950683,32.578718148918284],
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Run the export.
doExport(inputs, us_image_base, us_kernel_buffer, us_region)
# Out:
# Running image export to Google Drive...
# Image export completed.

# %%
def doPrediction(out_image_base, user_folder, kernel_buffer, region):
  """Perform inference on exported imagery, upload to Earth Engine.
  """

  print('Looking for TFRecord files...')

  # Get a list of all the files in the output bucket.
  # gdrive
  # filesList = !ls -1 'drive/My Drive/'{FOLDER}
  filesList = !gsutil ls 'gs://'{BUCKET}'/'{FOLDER}
  # Get only the files generated by the image export.
  exportFilesList = [s for s in filesList if out_image_base in s]

  # Get the list of image files and the JSON mixer file.
  imageFilesList = []
  jsonFile = None
  for f in exportFilesList:
    if f.endswith('.tfrecord.gz'):
      imageFilesList.append(f)
    elif f.endswith('.json'):
      jsonFile = f

  # Make sure the files are in the right order.
  imageFilesList.sort()
  # gdrive
  # for i, file in enumerate(imageFilesList):
  #   imageFilesList[i] = 'drive/My Drive/' + FOLDER + '/' + file
  from pprint import pprint
  pprint(imageFilesList)
  print(jsonFile)

  import json
  # Load the contents of the mixer file to a JSON object.
  # gdrive
  # jsonText = !cat 'drive/My Drive/'{FOLDER}'/'{jsonFile}
  jsonText = !gsutil cat {jsonFile}
  # Get a single string w/ newlines from the IPython.utils.text.SList
  mixer = json.loads(jsonText.nlstr)
  pprint(mixer)
  patches = mixer['totalPatches']

  # Get set up for prediction.
  x_buffer = int(kernel_buffer[0] / 2)
  y_buffer = int(kernel_buffer[1] / 2)

  buffered_shape = [
      KERNEL_SHAPE[0] + kernel_buffer[0],
      KERNEL_SHAPE[1] + kernel_buffer[1]]

  imageColumns = [
    tf.io.FixedLenFeature(shape=buffered_shape, dtype=tf.float32)
      for k in BANDS
  ]

  imageFeaturesDict = dict(zip(BANDS, imageColumns))

  def parse_image(example_proto):
    return tf.io.parse_single_example(example_proto, imageFeaturesDict)

  def toTupleImage(inputs):
    inputsList = [inputs.get(key) for key in BANDS]
    stacked = tf.stack(inputsList, axis=0)
    stacked = tf.transpose(stacked, [1, 2, 0])
    return stacked

   # Create a dataset from the TFRecord file(s) in Google Drive.
  imageDataset = tf.data.TFRecordDataset(imageFilesList, compression_type='GZIP')
  imageDataset = imageDataset.map(parse_image, num_parallel_calls=5)
  imageDataset = imageDataset.map(toTupleImage).batch(1)

  # Perform inference.
  print('Running predictions...')
  predictions = m.predict(imageDataset, steps=patches, verbose=1)
  # print(predictions[0])

  print('Writing predictions...')
  # gDrive
  # out_image_file = 'drive/My Drive/' + FOLDER + '/' + out_image_base + '.TFRecord'
  out_image_file = 'gs://' + BUCKET + '/' + FOLDER + '/' + out_image_base + '.TFRecord'
  writer = tf.io.TFRecordWriter(out_image_file)
  patches = 0
  for predictionPatch in predictions:
    print('Writing patch ' + str(patches) + '...')
    predictionPatch = predictionPatch[
        x_buffer:x_buffer+KERNEL_SIZE, y_buffer:y_buffer+KERNEL_SIZE]

    # Create an example.
    example = tf.train.Example(
      features=tf.train.Features(
        feature={
          'impervious': tf.train.Feature(
              float_list=tf.train.FloatList(
                  value=predictionPatch.flatten()))
        }
      )
    )
    # Write the example.
    writer.write(example.SerializeToString())
    patches += 1

  writer.close()

  # Start the upload.
  out_image_asset = user_folder + '/' + out_image_base
  # !earthengine upload image --asset_id={out_image_asset} {out_image_file} {jsonFile}

# %%
# Run the prediction.
doPrediction(us_image_base, user_folder, us_kernel_buffer, us_region)
# Out:
# Looking for TFRecord files...
# ['gs://cs6140/dataset/region_US_00000.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00001.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00002.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00003.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00004.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00005.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00006.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00007.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00008.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00009.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00010.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00011.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00012.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00013.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00014.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00015.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00016.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00017.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00018.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00019.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00020.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00021.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00022.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00023.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00024.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00025.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00026.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00027.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00028.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00029.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00030.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00031.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00032.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00033.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00034.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00035.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00036.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00037.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00038.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00039.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00040.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00041.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00042.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00043.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00044.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00045.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00046.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00047.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00048.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00049.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00050.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00051.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00052.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00053.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00054.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00055.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00056.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00057.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00058.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00059.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00060.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00061.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00062.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00063.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00064.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00065.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00066.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00067.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00068.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00069.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00070.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00071.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00072.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00073.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00074.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00075.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00076.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00077.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00078.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00079.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00080.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00081.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00082.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00083.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00084.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00085.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00086.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00087.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00088.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00089.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00090.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00091.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00092.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00093.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00094.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00095.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00096.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00097.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00098.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00099.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00100.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00101.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00102.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00103.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00104.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00105.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00106.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00107.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00108.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00109.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00110.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00111.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00112.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00113.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00114.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00115.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00116.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00117.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00118.tfrecord.gz',
#  'gs://cs6140/dataset/region_US_00119.tfrecord.gz']
# gs://cs6140/dataset/region_US_mixer.json
# {'patchDimensions': [256, 256],
#  'patchesPerRow': 100,
#  'projection': {'affine': {'doubleMatrix': [0.002245788210298804,
#                                             0.0,
#                                             -124.81866294019721,
#                                             0.0,
#                                             -0.002245788210298804,
#                                             49.10640500639364]},
#                 'crs': 'EPSG:4326'},
#  'totalPatches': 4200}
# Running predictions...
# 4200/4200 [==============================] - 152s 34ms/step
# Writing predictions...
# Writing patch 0...
# Writing patch 1...
# Writing patch 2...
# Writing patch 3...
# Writing patch 4...
# Writing patch 5...
# Writing patch 6...
# Writing patch 7...
# Writing patch 8...
# Writing patch 9...
# Writing patch 10...
# Writing patch 11...
# Writing patch 12...
# Writing patch 13...
# Writing patch 14...
# Writing patch 15...
# Writing patch 16...
# Writing patch 17...
# Writing patch 18...
# Writing patch 19...
# Writing patch 20...
# Writing patch 21...
# Writing patch 22...
# Writing patch 23...
# Writing patch 24...
# Writing patch 25...
# Writing patch 26...
# Writing patch 27...
# Writing patch 28...
# Writing patch 29...
# Writing patch 30...
# Writing patch 31...
# Writing patch 32...
# Writing patch 33...
# Writing patch 34...
# Writing patch 35...
# Writing patch 36...
# Writing patch 37...
# Writing patch 38...
# Writing patch 39...
# Writing patch 40...
# Writing patch 41...
# Writing patch 42...
# Writing patch 43...
# Writing patch 44...
# Writing patch 45...
# Writing patch 46...
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='predicted US',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7dbcd037ebaf70b006ea45c9e89a9226 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7dbcd037ebaf70b006ea45c9e89a9226&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7dbcd037ebaf70b006ea45c9e89a9226 = L.map(
#                 &quot;map_7dbcd037ebaf70b006ea45c9e89a9226&quot;,
#                 {
#                     center: [35.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd88dc198a90490686ca75f921518a4a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7dbcd037ebaf70b006ea45c9e89a9226);
#
#
#             var tile_layer_a591dc68195919fcdefa7117acba7502 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/0b51ab7219dbd50bc86c63470b683fd0-54147d8f5f5342ca8c9c89948a113542/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7dbcd037ebaf70b006ea45c9e89a9226);
#
#
#             var layer_control_0a10f8e3faaf5d8f83cceee9c315f72b = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_fd88dc198a90490686ca75f921518a4a,
#                 },
#                 overlays :  {
#                     &quot;predicted US&quot; : tile_layer_a591dc68195919fcdefa7117acba7502,
#                 },
#             };
#             L.control.layers(
#                 layer_control_0a10f8e3faaf5d8f83cceee9c315f72b.base_layers,
#                 layer_control_0a10f8e3faaf5d8f83cceee9c315f72b.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_7dbcd037ebaf70b006ea45c9e89a9226);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
countries = ee.FeatureCollection("FAO/GAUL/2015/level0")
canada = countries.filter(ee.Filter.eq('ADM0_CODE', 46))
out_image = ee.Image(user_folder + '/' + ca_image_base)
out_image = out_image.clip(canada)
mapid = out_image.getMapId({'min': 0, 'max': 1, 'palette': ['bbe029', '0a9501', '074b03']})
map = folium.Map(location=[49.2827, -123.1207])
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='predicted Canada',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_446216cb1ce4d3484a11fc4ffe94449d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_446216cb1ce4d3484a11fc4ffe94449d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_446216cb1ce4d3484a11fc4ffe94449d = L.map(
#                 &quot;map_446216cb1ce4d3484a11fc4ffe94449d&quot;,
#                 {
#                     center: [49.2827, -123.1207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b059ae2fa8e4ffcc36cecac0c61522c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_446216cb1ce4d3484a11fc4ffe94449d);
#
#
#             var tile_layer_0828bd7faec778139c5920261677a8d8 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/fb79823244e3af51b5672dd92530e06c-fcda45d02c19718aa6ba7780af821851/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_446216cb1ce4d3484a11fc4ffe94449d);
#
#
#             var layer_control_b44c1a4a46aa77651d3f0c9ab13746c1 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_0b059ae2fa8e4ffcc36cecac0c61522c,
#                 },
#                 overlays :  {
#                     &quot;predicted Canada&quot; : tile_layer_0828bd7faec778139c5920261677a8d8,
#                 },
#             };
#             L.control.layers(
#                 layer_control_b44c1a4a46aa77651d3f0c9ab13746c1.base_layers,
#                 layer_control_b44c1a4a46aa77651d3f0c9ab13746c1.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_446216cb1ce4d3484a11fc4ffe94449d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Reference
#
# We acknowledge the use of [TensorFlow example workflows](https://developers.google.com/earth-engine/guides/tf_examples) for inspiration and guidance in this notebook.
