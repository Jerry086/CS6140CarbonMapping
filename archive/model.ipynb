# %%
# Tensorflow setup.
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# Set global variables

# %%
# Specify names locations for outputs in Google Cloud.
BUCKET = 'cs6140'
FOLDER = 'dataset'
TRAINING_BASE = 'training_patches'
EVAL_BASE = 'eval_patches'

# Specify feature bands to the model and the response variable.
MODIS_BANDS = ['EVI']
COPERNICUS_BANDS = ['discrete_classification', 'forest_type']
TERRA_BANDS = ['Percent_Tree_Cover', 'Percent_NonTree_Vegetation']
BANDS = MODIS_BANDS + COPERNICUS_BANDS + TERRA_BANDS
RESPONSE = 'annualNPP'
FEATURES = BANDS + [RESPONSE]

# Specify the size and shape of patches (256x256 pixels images) expected by the model.
KERNEL_SIZE = 256
KERNEL_SHAPE = [KERNEL_SIZE, KERNEL_SIZE]

# Columns for input features and response
COLUMNS = [
  # Configuration for parsing a fixed-length input feature.
  tf.io.FixedLenFeature(shape=KERNEL_SHAPE, dtype=tf.float32) for k in FEATURES
]
# Label each column with feature name by dictionary
FEATURES_DICT = dict(zip(FEATURES, COLUMNS))

# Sizes of the training and evaluation datasets.
# TODO: modify as needed
TRAIN_SIZE = 10000
EVAL_SIZE = 5000

# Specify model training parameters.
# TODO: modify as needed
BATCH_SIZE = 16
EPOCHS = 2
BUFFER_SIZE = 500
OPTIMIZER = 'Adam'
LOSS = 'MeanSquaredError'
METRICS = ['RootMeanSquaredError']

# %% [markdown]
# Load the data exported from Earth Engine into a tf.data.Dataset.

# %%
def parse_tfrecord(example_proto):
  """The parsing function.
  Read a serialized example into the structure defined by FEATURES_DICT.
  Args:
    example_proto: a serialized Example.
  Returns:
    A dictionary of tensors, keyed by feature name.
  """
  return tf.io.parse_single_example(example_proto, FEATURES_DICT)


def to_tuple(inputs):
  """Function to convert a dictionary of tensors to a tuple of (inputs, outputs).
  Turn the tensors returned by parse_tfrecord into a stack in HWC shape.
  Args:
    inputs: A dictionary of tensors, keyed by feature name.
  Returns:
    A tuple of (inputs, outputs).
  """
  inputsList = [inputs.get(key) for key in FEATURES]
  stacked = tf.stack(inputsList, axis=0)
  # Convert from CHW to HWC
  stacked = tf.transpose(stacked, [1, 2, 0])
  return stacked[:,:,:len(BANDS)], stacked[:,:,len(BANDS):]


def get_dataset(pattern):
  """Function to read, parse and format to tuple a set of input tfrecord files.
  Get all the files matching the pattern, parse and convert to tuple.
  Args:
    pattern: A file pattern to match in a Cloud Storage bucket.
  Returns:
    A tf.data.Dataset
  """
  glob = tf.io.gfile.glob(pattern)
  dataset = tf.data.TFRecordDataset(glob, compression_type='GZIP')
  dataset = dataset.map(parse_tfrecord, num_parallel_calls=5)
  dataset = dataset.map(to_tuple, num_parallel_calls=5)
  return dataset

# %% [markdown]
# Use the helpers to read in the training dataset. Print the first record to check.

# %%
def get_training_dataset():
	"""Get the preprocessed training dataset
  Returns:
    A tf.data.Dataset of training data.
  """
	# directory for Google Drive
	# root_dir = 'drive/My Drive/'
	# glob = root_dir + FOLDER + '/' + 'training_patches' + '*'
	glob = 'gs://' + BUCKET + '/' + FOLDER + '/' + TRAINING_BASE + '*'
	dataset = get_dataset(glob)
	# shuffle in n iterations, random pick one element from buffer in each iteration
	# batch in size BATCH_SIZE
	# repeat when all element are comsumed
	dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
#          [0.6136275 , 0.57      , 0.8       , 0.8452381 , 0.20408164],
#          [0.62770295, 0.57      , 0.8       , 0.8452381 , 0.18367347]],
#
#         [[0.5767047 , 0.63      , 0.        , 0.41666666, 0.48979592],
#          [0.628249  , 0.63      , 0.        , 0.63095236, 0.35714287],
#          [0.7107098 , 0.57      , 0.8       , 0.86904764, 0.1734694 ],
#          ...,
#          [0.56982875, 0.57      , 0.8       , 0.8095238 , 0.13265306],
#          [0.5962101 , 0.57      , 0.8       , 0.8333333 , 0.21428572],
#          [0.6191232 , 0.57      , 0.8       , 0.8214286 , 0.2244898 ]],
#
#         ...,
#
#         [[0.6659858 , 0.57      , 0.8       , 0.8333333 , 0.19387755],
#          [0.6663296 , 0.57      , 0.8       , 0.8333333 , 0.20408164],
#          [0.6661476 , 0.57      , 0.8       , 0.8333333 , 0.23469388],
#          ...,
#          [0.63382053, 0.57      , 0.8       , 0.8333333 , 0.2244898 ],
#          [0.63382053, 0.57      , 0.8       , 0.8333333 , 0.2244898 ],
#          [0.6232134 , 0.57      , 0.8       , 0.8333333 , 0.23469388]],
#
#         [[0.6373647 , 0.57      , 0.8       , 0.71428573, 0.29591838],
#          [0.634402  , 0.57      , 0.8       , 0.75      , 0.30612245],
#          [0.634402  , 0.57      , 0.8       , 0.75      , 0.30612245],
#          ...,
#          [0.6502116 , 0.57      , 0.8       , 0.8214286 , 0.23469388],
#          [0.6304433 , 0.57      , 0.8       , 0.8452381 , 0.21428572],
#          [0.6091986 , 0.57      , 0.8       , 0.8452381 , 0.2244898 ]],
#
#         [[0.64665735, 0.57      , 0.8       , 0.5595238 , 0.45918366],
#          [0.63666195, 0.57      , 0.8       , 0.53571427, 0.47959185],
#          [0.63666195, 0.57      , 0.8       , 0.53571427, 0.47959185],
#          ...,
#          [0.6568347 , 0.57      , 0.8       , 0.8333333 , 0.2244898 ],
#          [0.6494886 , 0.57      , 0.8       , 0.8214286 , 0.23469388],
#          [0.6659706 , 0.57      , 0.8       , 0.8333333 , 0.21428572]]]],
#       dtype=float32)>, <tf.Tensor: shape=(16, 256, 256, 1), dtype=float32, numpy=
# array([[[[0.346301  ],
#          [0.34602773],
#          [0.34479815],
#          ...,
#          [0.36870688],
#          [0.36734065],
#          [0.3673065 ]],
#
#         [[0.35299543],
#          [0.3486577 ],
#          [0.34592527],
#          ...,
#          [0.36635017],
#          [0.36710158],
#          [0.36775053]],
#
#         [[0.354225  ],
#          [0.3499556 ],
#          [0.34681332],
#          ...,
#          [0.343227  ],
#          [0.37242982],
#          [0.37307876]],
#
#         ...,
#
#         [[0.27751213],
#          [0.27846846],
#          [0.27819523],
#          ...,
#          [0.346301  ],
#          [0.3258761 ],
#          [0.3229387 ]],
#
#         [[0.2802104 ],
#          [0.27816108],
#          [0.2776829 ],
#          ...,
#          [0.33356103],
#          [0.3313068 ],
#          [0.33581528]],
#
#         [[0.27911744],
#          [0.2761459 ],
#          [0.2777512 ],
#          ...,
#          [0.33936745],
#          [0.33639592],
#          [0.33096522]]],
#
#
#        [[[0.3129312 ],
#          [0.3104037 ],
#          [0.3081836 ],
#          ...,
#          [0.25203225],
#          [0.3484186 ],
#          [0.3640276 ]],
#
#         [[0.31323862],
#          [0.30739805],
#          [0.30746636],
#          ...,
#          [0.3815493 ],
#          [0.37529886],
#          [0.37157592]],
#
#         [[0.31204316],
#          [0.3075005 ],
#          [0.30763713],
#          ...,
#          [0.37239566],
#          [0.37140515],
#          [0.37837285]],
#
#         ...,
#
#         [[0.31036955],
#          [0.30678326],
#          [0.29984972],
#          ...,
#          [0.34046042],
#          [0.34049457],
#          [0.3445249 ]],
#
#         [[0.30913997],
#          [0.30688572],
#          [0.29906413],
#          ...,
#          [0.32628596],
#          [0.34049457],
#          [0.34988728]],
#
#         [[0.31399003],
#          [0.3113942 ],
#          [0.30961815],
#          ...,
#          [0.3478721 ],
#          [0.35029715],
#          [0.3512535 ]]],
#
#
#        [[[0.        ],
#          [0.22296605],
#          [0.20213129],
#          ...,
#          [0.33004305],
#          [0.33017966],
#          [0.32867682]],
#
#         [[0.        ],
#          [0.23345174],
#          [0.23533028],
#          ...,
#          [0.32645673],
#          [0.32871097],
#          [0.326081  ]],
#
#         [[0.        ],
#          [0.        ],
#          [0.        ],
#          ...,
#          [0.32799372],
#          [0.32683244],
#          [0.32577363]],
#
#         ...,
#
#         [[0.33967483],
#          [0.33936745],
#          [0.33987978],
#          ...,
#          [0.3368741 ],
#          [0.33707905],
#          [0.33342442]],
#
#         [[0.33608854],
#          [0.33683994],
#          [0.548808  ],
#          ...,
#          [0.33332196],
#          [0.33376595],
#          [0.3329804 ]],
#
#         [[0.33646423],
#          [0.33554205],
#          [0.33571282],
#          ...,
#          [0.3330487 ],
#          [0.3340392 ],
#          [0.334654  ]]],
#
#
#        ...,
#
#
#        [[[0.34148508],
#          [0.33868435],
#          [0.3399481 ],
#          ...,
#          [0.29783455],
#          [0.2942141 ],
#          [0.2972539 ]],
#
#         [[0.34513968],
#          [0.3432953 ],
#          [0.34257805],
#          ...,
#          [0.29363343],
#          [0.2916866 ],
#          [0.29441902]],
#
#         [[0.3413143 ],
#          [0.34022132],
#          [0.34257805],
#          ...,
#          [0.29407746],
#          [0.29537538],
#          [0.29708314]],
#
#         ...,
#
#         [[0.32871097],
#          [0.32918915],
#          [0.329155  ],
#          ...,
#          [0.31839606],
#          [0.31907916],
#          [0.3237243 ]],
#
#         [[0.32789126],
#          [0.3276863 ],
#          [0.32696906],
#          ...,
#          [0.32147005],
#          [0.3261493 ],
#          [0.325193  ]],
#
#         [[0.3286085 ],
#          [0.32980394],
#          [0.3288476 ],
#          ...,
#          [0.319045  ],
#          [0.32037708],
#          [0.32054785]]],
#
#
#        [[[0.32252887],
#          [0.32164082],
#          [0.33902588],
#          ...,
#          [0.38633102],
#          [0.38387185],
#          [0.3789535 ]],
#
#         [[0.34438828],
#          [0.34250975],
#          [0.3445249 ],
#          ...,
#          [0.39138603],
#          [0.38838035],
#          [0.38107112]],
#
#         [[0.34059703],
#          [0.33851355],
#          [0.34145093],
#          ...,
#          [0.38684335],
#          [0.38018307],
#          [0.3836669 ]],
#
#         ...,
#
#         [[0.32047954],
#          [0.31788373],
#          [0.31713232],
#          ...,
#          [0.3558303 ],
#          [0.3534736 ],
#          [0.34616435]],
#
#         [[0.32037708],
#          [0.31880593],
#          [0.31484392],
#          ...,
#          [0.3487943 ],
#          [0.34688163],
#          [0.34930664]],
#
#         [[0.31853268],
#          [0.31791788],
#          [0.3173714 ],
#          ...,
#          [0.3446957 ],
#          [0.3534053 ],
#          [0.3510827 ]]],
#
#
#        [[[0.        ],
#          [0.        ],
#          [0.        ],
#          ...,
#          [0.3566159 ],
#          [0.35678667],
#          [0.35688913]],
#
#         [[0.        ],
#          [0.        ],
#          [0.        ],
#          ...,
#          [0.35665005],
#          [0.35466903],
#          [0.352688  ]],
#
#         [[0.2920623 ],
#          [0.3093449 ],
#          [0.3352005 ],
#          ...,
#          [0.35904092],
#          [0.35835782],
#          [0.3563085 ]],
#
#         ...,
#
#         [[0.30189905],
#          [0.30487055],
#          [0.3071248 ],
#          ...,
#          [0.34028962],
#          [0.33745474],
#          [0.33950406]],
#
#         [[0.31149668],
#          [0.30763713],
#          [0.30763713],
#          ...,
#          [0.34462735],
#          [0.339265  ],
#          [0.33629346]],
#
#         [[0.32003552],
#          [0.31723478],
#          [0.31955734],
#          ...,
#          [0.34083614],
#          [0.33783045],
#          [0.33561036]]]], dtype=float32)>)

# %%
def get_eval_dataset():
	"""Get the preprocessed evaluation dataset
  Returns:
    A tf.data.Dataset of evaluation data.
  """
	# root_dir = 'drive/My Drive/'
	# glob = root_dir + FOLDER + '/' + 'eval_patches' + '*'
	glob = 'gs://' + BUCKET + '/' + FOLDER + '/' + EVAL_BASE + '*'
	dataset = get_dataset(glob)
	dataset = dataset.batch(1).repeat()
	return dataset

evaluation = get_eval_dataset()
evaluation
# Out:
# <RepeatDataset element_spec=(TensorSpec(shape=(None, 256, 256, 5), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None))>

# %% [markdown]
# Keras implementation of the U-Net model.

# %%
from keras.models import *
from keras.layers import *
from keras import metrics
from keras import optimizers
from keras import losses

# TODO: test other activation functions

def conv_block(input_tensor, num_filters):
	encoder = Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
	encoder = BatchNormalization()(encoder)
	encoder = Activation('relu')(encoder)
	encoder = Conv2D(num_filters, (3, 3), padding='same')(encoder)
	encoder = BatchNormalization()(encoder)
	encoder = Activation('relu')(encoder)
	return encoder

def encoder_block(input_tensor, num_filters):
	encoder = conv_block(input_tensor, num_filters)
	encoder_pool = MaxPooling2D((2, 2), strides=(2, 2))(encoder)
	return encoder_pool, encoder

def decoder_block(input_tensor, concat_tensor, num_filters):
	decoder = Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
	decoder = concatenate([concat_tensor, decoder], axis=-1)
	decoder = BatchNormalization()(decoder)
	decoder = Activation('relu')(decoder)
	decoder = Conv2D(num_filters, (3, 3), padding='same')(decoder)
	decoder = BatchNormalization()(decoder)
	decoder = Activation('relu')(decoder)
	decoder = Conv2D(num_filters, (3, 3), padding='same')(decoder)
	decoder = BatchNormalization()(decoder)
	decoder = Activation('relu')(decoder)
	return decoder

def get_model():
	inputs = Input(shape=[None, None, len(BANDS)]) # 256
	encoder0_pool, encoder0 = encoder_block(inputs, 32) # 128
	encoder1_pool, encoder1 = encoder_block(encoder0_pool, 64) # 64
	encoder2_pool, encoder2 = encoder_block(encoder1_pool, 128) # 32
	encoder3_pool, encoder3 = encoder_block(encoder2_pool, 256) # 16
	encoder4_pool, encoder4 = encoder_block(encoder3_pool, 512) # 8
	center = conv_block(encoder4_pool, 1024) # center
	decoder4 = decoder_block(center, encoder4, 512) # 16
	decoder3 = decoder_block(decoder4, encoder3, 256) # 32
	decoder2 = decoder_block(decoder3, encoder2, 128) # 64
	decoder1 = decoder_block(decoder2, encoder1, 64) # 128
	decoder0 = decoder_block(decoder1, encoder0, 32) # 256
	outputs = Conv2D(1, (1, 1), activation='sigmoid')(decoder0)

	model = Model(inputs=[inputs], outputs=[outputs])

	model.compile(
		optimizer=optimizers.get(OPTIMIZER),
		loss=losses.get(LOSS),
		metrics=[metrics.get(metric) for metric in METRICS])

	return model

# %% [markdown]
# The model summary

# %%
m = get_model()
m.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, None, None,  0           []
#                                  5)]
#
#  conv2d_46 (Conv2D)             (None, None, None,   1472        ['input_3[0][0]']
#                                 32)
#
#  batch_normalization_54 (BatchN  (None, None, None,   128        ['conv2d_46[0][0]']
#  ormalization)                  32)
#
#  activation_54 (Activation)     (None, None, None,   0           ['batch_normalization_54[0][0]']
#                                 32)
#
#  conv2d_47 (Conv2D)             (None, None, None,   9248        ['activation_54[0][0]']
#                                 32)
#
#  batch_normalization_55 (BatchN  (None, None, None,   128        ['conv2d_47[0][0]']
#  ormalization)                  32)
#
#  activation_55 (Activation)     (None, None, None,   0           ['batch_normalization_55[0][0]']
#                                 32)
#
#  max_pooling2d_10 (MaxPooling2D  (None, None, None,   0          ['activation_55[0][0]']
#  )                              32)
#
#  conv2d_48 (Conv2D)             (None, None, None,   18496       ['max_pooling2d_10[0][0]']
#                                 64)
#
#  batch_normalization_56 (BatchN  (None, None, None,   256        ['conv2d_48[0][0]']
#  ormalization)                  64)
#
#  activation_56 (Activation)     (None, None, None,   0           ['batch_normalization_56[0][0]']
#                                 64)
#
#  conv2d_49 (Conv2D)             (None, None, None,   36928       ['activation_56[0][0]']
#                                 64)
#
#  batch_normalization_57 (BatchN  (None, None, None,   256        ['conv2d_49[0][0]']
#  ormalization)                  64)
#
#  activation_57 (Activation)     (None, None, None,   0           ['batch_normalization_57[0][0]']
#                                 64)
#
#  max_pooling2d_11 (MaxPooling2D  (None, None, None,   0          ['activation_57[0][0]']
#  )                              64)
#
#  conv2d_50 (Conv2D)             (None, None, None,   73856       ['max_pooling2d_11[0][0]']
#                                 128)
#
#  batch_normalization_58 (BatchN  (None, None, None,   512        ['conv2d_50[0][0]']
#  ormalization)                  128)
#
#  activation_58 (Activation)     (None, None, None,   0           ['batch_normalization_58[0][0]']
#                                 128)
#
#  conv2d_51 (Conv2D)             (None, None, None,   147584      ['activation_58[0][0]']
#                                 128)
#
#  batch_normalization_59 (BatchN  (None, None, None,   512        ['conv2d_51[0][0]']
#  ormalization)                  128)
#
#  activation_59 (Activation)     (None, None, None,   0           ['batch_normalization_59[0][0]']
#                                 128)
#
#  max_pooling2d_12 (MaxPooling2D  (None, None, None,   0          ['activation_59[0][0]']
#  )                              128)
#
#  conv2d_52 (Conv2D)             (None, None, None,   295168      ['max_pooling2d_12[0][0]']
#                                 256)
#
#  batch_normalization_60 (BatchN  (None, None, None,   1024       ['conv2d_52[0][0]']
#  ormalization)                  256)
#
#  activation_60 (Activation)     (None, None, None,   0           ['batch_normalization_60[0][0]']
#                                 256)
#
#  conv2d_53 (Conv2D)             (None, None, None,   590080      ['activation_60[0][0]']
#                                 256)
#
#  batch_normalization_61 (BatchN  (None, None, None,   1024       ['conv2d_53[0][0]']
#  ormalization)                  256)
#
#  activation_61 (Activation)     (None, None, None,   0           ['batch_normalization_61[0][0]']
#                                 256)
#
#  max_pooling2d_13 (MaxPooling2D  (None, None, None,   0          ['activation_61[0][0]']
#  )                              256)
#
#  conv2d_54 (Conv2D)             (None, None, None,   1180160     ['max_pooling2d_13[0][0]']
#                                 512)
#
#  batch_normalization_62 (BatchN  (None, None, None,   2048       ['conv2d_54[0][0]']
#  ormalization)                  512)
#
#  activation_62 (Activation)     (None, None, None,   0           ['batch_normalization_62[0][0]']
#                                 512)
#
#  conv2d_55 (Conv2D)             (None, None, None,   2359808     ['activation_62[0][0]']
#                                 512)
#
#  batch_normalization_63 (BatchN  (None, None, None,   2048       ['conv2d_55[0][0]']
#  ormalization)                  512)
#
#  activation_63 (Activation)     (None, None, None,   0           ['batch_normalization_63[0][0]']
#                                 512)
#
#  max_pooling2d_14 (MaxPooling2D  (None, None, None,   0          ['activation_63[0][0]']
#  )                              512)
#
#  conv2d_56 (Conv2D)             (None, None, None,   4719616     ['max_pooling2d_14[0][0]']
#                                 1024)
#
#  batch_normalization_64 (BatchN  (None, None, None,   4096       ['conv2d_56[0][0]']
#  ormalization)                  1024)
#
#  activation_64 (Activation)     (None, None, None,   0           ['batch_normalization_64[0][0]']
#                                 1024)
#
#  conv2d_57 (Conv2D)             (None, None, None,   9438208     ['activation_64[0][0]']
#                                 1024)
#
#  batch_normalization_65 (BatchN  (None, None, None,   4096       ['conv2d_57[0][0]']
#  ormalization)                  1024)
#
#  activation_65 (Activation)     (None, None, None,   0           ['batch_normalization_65[0][0]']
#                                 1024)
#
#  conv2d_transpose_10 (Conv2DTra  (None, None, None,   2097664    ['activation_65[0][0]']
#  nspose)                        512)
#
#  concatenate_10 (Concatenate)   (None, None, None,   0           ['activation_63[0][0]',
#                                 1024)                             'conv2d_transpose_10[0][0]']
#
#  batch_normalization_66 (BatchN  (None, None, None,   4096       ['concatenate_10[0][0]']
#  ormalization)                  1024)
#
#  activation_66 (Activation)     (None, None, None,   0           ['batch_normalization_66[0][0]']
#                                 1024)
#
#  conv2d_58 (Conv2D)             (None, None, None,   4719104     ['activation_66[0][0]']
#                                 512)
#
#  batch_normalization_67 (BatchN  (None, None, None,   2048       ['conv2d_58[0][0]']
#  ormalization)                  512)
#
#  activation_67 (Activation)     (None, None, None,   0           ['batch_normalization_67[0][0]']
#                                 512)
#
#  conv2d_59 (Conv2D)             (None, None, None,   2359808     ['activation_67[0][0]']
#                                 512)
#
#  batch_normalization_68 (BatchN  (None, None, None,   2048       ['conv2d_59[0][0]']
#  ormalization)                  512)
#
#  activation_68 (Activation)     (None, None, None,   0           ['batch_normalization_68[0][0]']
#                                 512)
#
#  conv2d_transpose_11 (Conv2DTra  (None, None, None,   524544     ['activation_68[0][0]']
#  nspose)                        256)
#
#  concatenate_11 (Concatenate)   (None, None, None,   0           ['activation_61[0][0]',
#                                 512)                              'conv2d_transpose_11[0][0]']
#
#  batch_normalization_69 (BatchN  (None, None, None,   2048       ['concatenate_11[0][0]']
#  ormalization)                  512)
#
#  activation_69 (Activation)     (None, None, None,   0           ['batch_normalization_69[0][0]']
#                                 512)
#
#  conv2d_60 (Conv2D)             (None, None, None,   1179904     ['activation_69[0][0]']
#                                 256)
#
#  batch_normalization_70 (BatchN  (None, None, None,   1024       ['conv2d_60[0][0]']
#  ormalization)                  256)
#
#  activation_70 (Activation)     (None, None, None,   0           ['batch_normalization_70[0][0]']
#                                 256)
#
#  conv2d_61 (Conv2D)             (None, None, None,   590080      ['activation_70[0][0]']
#                                 256)
#
#  batch_normalization_71 (BatchN  (None, None, None,   1024       ['conv2d_61[0][0]']
#  ormalization)                  256)
#
#  activation_71 (Activation)     (None, None, None,   0           ['batch_normalization_71[0][0]']
#                                 256)
#
#  conv2d_transpose_12 (Conv2DTra  (None, None, None,   131200     ['activation_71[0][0]']
#  nspose)                        128)
#
#  concatenate_12 (Concatenate)   (None, None, None,   0           ['activation_59[0][0]',
#                                 256)                              'conv2d_transpose_12[0][0]']
#
#  batch_normalization_72 (BatchN  (None, None, None,   1024       ['concatenate_12[0][0]']
#  ormalization)                  256)
#
#  activation_72 (Activation)     (None, None, None,   0           ['batch_normalization_72[0][0]']
#                                 256)
#
#  conv2d_62 (Conv2D)             (None, None, None,   295040      ['activation_72[0][0]']
#                                 128)
#
#  batch_normalization_73 (BatchN  (None, None, None,   512        ['conv2d_62[0][0]']
#  ormalization)                  128)
#
#  activation_73 (Activation)     (None, None, None,   0           ['batch_normalization_73[0][0]']
#                                 128)
#
#  conv2d_63 (Conv2D)             (None, None, None,   147584      ['activation_73[0][0]']
#                                 128)
#
#  batch_normalization_74 (BatchN  (None, None, None,   512        ['conv2d_63[0][0]']
#  ormalization)                  128)
#
#  activation_74 (Activation)     (None, None, None,   0           ['batch_normalization_74[0][0]']
#                                 128)
#
#  conv2d_transpose_13 (Conv2DTra  (None, None, None,   32832      ['activation_74[0][0]']
#  nspose)                        64)
#
#  concatenate_13 (Concatenate)   (None, None, None,   0           ['activation_57[0][0]',
#                                 128)                              'conv2d_transpose_13[0][0]']
#
#  batch_normalization_75 (BatchN  (None, None, None,   512        ['concatenate_13[0][0]']
#  ormalization)                  128)
#
#  activation_75 (Activation)     (None, None, None,   0           ['batch_normalization_75[0][0]']
#                                 128)
#
#  conv2d_64 (Conv2D)             (None, None, None,   73792       ['activation_75[0][0]']
#                                 64)
#
#  batch_normalization_76 (BatchN  (None, None, None,   256        ['conv2d_64[0][0]']
#  ormalization)                  64)
#
#  activation_76 (Activation)     (None, None, None,   0           ['batch_normalization_76[0][0]']
#                                 64)
#
#  conv2d_65 (Conv2D)             (None, None, None,   36928       ['activation_76[0][0]']
#                                 64)
#
#  batch_normalization_77 (BatchN  (None, None, None,   256        ['conv2d_65[0][0]']
#  ormalization)                  64)
#
#  activation_77 (Activation)     (None, None, None,   0           ['batch_normalization_77[0][0]']
#                                 64)
#
#  conv2d_transpose_14 (Conv2DTra  (None, None, None,   8224       ['activation_77[0][0]']
#  nspose)                        32)
#
#  concatenate_14 (Concatenate)   (None, None, None,   0           ['activation_55[0][0]',
#                                 64)                               'conv2d_transpose_14[0][0]']
#
#  batch_normalization_78 (BatchN  (None, None, None,   256        ['concatenate_14[0][0]']
#  ormalization)                  64)
#
#  activation_78 (Activation)     (None, None, None,   0           ['batch_normalization_78[0][0]']
#                                 64)
#
#  conv2d_66 (Conv2D)             (None, None, None,   18464       ['activation_78[0][0]']
#                                 32)
#
#  batch_normalization_79 (BatchN  (None, None, None,   128        ['conv2d_66[0][0]']
#  ormalization)                  32)
#
#  activation_79 (Activation)     (None, None, None,   0           ['batch_normalization_79[0][0]']
#                                 32)
#
#  conv2d_67 (Conv2D)             (None, None, None,   9248        ['activation_79[0][0]']
#                                 32)
#
#  batch_normalization_80 (BatchN  (None, None, None,   128        ['conv2d_67[0][0]']
#  ormalization)                  32)
#
#  activation_80 (Activation)     (None, None, None,   0           ['batch_normalization_80[0][0]']
#                                 32)
#
#  conv2d_68 (Conv2D)             (None, None, None,   33          ['activation_80[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 31,127,073
# Trainable params: 31,111,073
# Non-trainable params: 16,000
# __________________________________________________________________________________________________

# %% [markdown]
# path to save model parameters

# %%
import os
checkpoint_path = 'training_1/cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)
checkpoint_dir
# Out:
# 'training_1'

# %% [markdown]
# callback function that saves the model weights

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %% [markdown]
# Train the model

# %%
m.fit(
    x=training,
    epochs=EPOCHS,
    steps_per_epoch=int(TRAIN_SIZE / BATCH_SIZE),
    validation_data=evaluation,
    validation_steps=EVAL_SIZE)

m.save_weights('./final/normalized')
# Out:
# Epoch 1/2
# 625/625 [==============================] - 415s 658ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1458
# Epoch 2/2
# 625/625 [==============================] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1033

# %%
# Restore the weights
m.load_weights('./final/normalized')

# Evaluate the model
loss, acc = m.evaluate(x=evaluation, verbose=2, steps=625)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 625/625 - 12s - loss: 0.0132 - root_mean_squared_error: 0.1148 - 12s/epoch - 20ms/step
# Restored model, accuracy: 11.48%
